# %% [markdown]
# <a href="https://colab.research.google.com/github/ertgrulyksk/Computer-Games-EDA/blob/main/Computer_Games_EDA_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns #data visualization 
sns.set_style("white")

# %%
Computer_Games = pd.read_csv("computer_games.csv")
Computer_Games
# Out:
#                                     Name                        Developer  \
# 0                                A-Men 2                     Bloober Team
# 1                                A-Train                          Artdink
# 2                             A-10 Cuba!              Parsoft Interactive
# 3                              A.D. 2044                  R.M.P. Software
# 4     A.D.A.M. Life's Greatest Mysteries  Columbia Healthcare Corporation
# ...                                  ...                              ...
# 1090                688(I) Hunter/Killer                   Sonalysts Inc.
# 1091                            7 Colors                       Gamos Ltd.
# 1092                                7554                      Emobi Games
# 1093                          7th Legion           Vision, Epic MegaGames
# 1094                  9: The Last Resort              Tribeca Interactive
#
#                              Producer                    Genre  \
# ...

# %%
Computer_Games.shape
# Out:
# (1095, 6)

# %%
print("Shape of the dataset is",Computer_Games.shape)
# Out:
# Shape of the dataset is (1095, 6)

# %%
Computer_Games.isna().value_counts()
# Out:
# Name   Developer  Producer  Genre  Operating System  Date Released
# False  False      False     False  False             False            1095
# dtype: int64

# %%
Computer_Games.describe()
# Out:
#                  Name Developer         Producer                 Genre  \
# count            1095      1095             1095                  1095
# unique           1094       583              489                   282
# top     A Hat in Time     Maxis  Electronic Arts  First-person shooter
# freq                2        30               84                   103
#
#          Operating System Date Released
# count                1095          1095
# unique                 83           915
# top     Microsoft Windows          1995
# freq                  600             9

# %%
Computer_Games['Developer'].value_counts()
# Out:
# Maxis                     30
# Valve                     20
# Square Enix               18
# Blizzard Entertainment    18
# Ubisoft Montreal          17
#                           ..
# Eagle Dynamics             1
# Mimimi Games               1
# Positech Games             1
# Zombie Studios             1
# Tribeca Interactive        1
# Name: Developer, Length: 583, dtype: int64

# %%
top_10_developers = Computer_Games['Developer'].value_counts().head(10)
top_10_developers
# Out:
# Maxis                          30
# Valve                          20
# Square Enix                    18
# Blizzard Entertainment         18
# Ubisoft Montreal               17
# Quiet River                    12
# BioWare                        11
# Strategic Simulations, Inc.    11
# Data Design Interactive        10
# TalonSoft                      10
# Name: Developer, dtype: int64

# %%
plt.style.use("bmh")
plt.figure(figsize=(15,10))
top_10_developers.plot(kind="barh",color="#9905E8",title="Top 10 Computer Games Developing Companies")

# %%
top_10_producers = Computer_Games['Producer'].value_counts().head(10)
top_10_producers
# Out:
# Electronic Arts           84
# Ubisoft                   44
# Square Enix               31
# Eidos Interactive         28
# Paradox Interactive       22
# Valve                     20
# Blizzard Entertainment    19
# Microsoft Game Studios    18
# Bethesda Softworks        15
# Activision                14
# Name: Producer, dtype: int64

# %%
plt.style.use("bmh")
plt.figure(figsize=(15,10))
top_10_producers.plot(kind="barh",color="#F25A05",title="Top 10 Computer Games Producing Companies")

# %%
top_10_game_genres = Computer_Games["Genre"].value_counts().head(10)
top_10_game_genres
# Out:
# First-person shooter    103
# RTS                      48
# Action-adventure         42
# Sports                   34
# Role-playing             33
# RPG                      30
# Action role-playing      29
# Life simulation          27
# Adventure                23
# Turn-based strategy      22
# Name: Genre, dtype: int64

# %%
plt.style.use("bmh")
plt.figure(figsize=(15,10))
top_10_game_genres.plot(kind="barh",color="#E8051F",title="Top 10 Computer Game Genres")

# %%
OS_of_Games = Computer_Games["Operating System"].value_counts().head(10)
OS_of_Games
# Out:
# Microsoft Windows                  600
# Microsoft Windows, macOS           191
# Microsoft Windows, Linux, macOS    141
# MS-DOS                              27
# Microsoft Windows, Linux            15
# Microsoft Windows, Mac OS X          7
# Microsoft Windows,                   6
# MS-DOS, Microsoft Windows            5
# DOS                                  5
# Microsoft Windows, OS X, Linux       5
# Name: Operating System, dtype: int64

# %%
plt.style.use("bmh")
plt.figure(figsize=(15,10))
OS_of_Games.plot(kind="barh",color="#F55347",title="Top 10 Computer Game Operating System")

# %%
import plotly.express as px

# %%
developer_data = pd.DataFrame(Computer_Games['Developer'].value_counts())
developer_data.rename(columns={"Developer": "Number of developer"}, inplace=True)
total_developer = developer_data["Number of developer"].sum()
developer_data["developer %"] = round(developer_data["Number of developer"] / total_developer * 100, 2)
developer_data["Name"] = developer_data.index


# pie plot
fig = px.pie(developer_data,
             values="developer %",
             names="Name",
             title="Developer of the Game",
             template="seaborn",width=1200,height=1000)
fig.update_traces(textposition="inside", textinfo="value+percent+label")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
developer_data = pd.DataFrame(Computer_Games['Developer'].value_counts().head(10))
developer_data.rename(columns={"Developer": "Number of developer"}, inplace=True)
total_developer = developer_data["Number of developer"].sum()
developer_data["developer %"] = round(developer_data["Number of developer"] / total_developer * 100, 2)
developer_data["Name"] = developer_data.index


# pie plot
fig = px.pie(developer_data,
             values="developer %",
             names="Name",
             title="Developer of the Game",
             template="seaborn",width=1200,height=1000)
fig.update_traces(textposition="inside", textinfo="value+percent+label")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
producer_data = pd.DataFrame(Computer_Games['Producer'].value_counts())
producer_data.rename(columns={"Producer": "Number of Producer"}, inplace=True)
total_producer = producer_data["Number of Producer"].sum()
producer_data["Producer %"] = round(producer_data["Number of Producer"] / total_producer * 100, 2)
producer_data["Name"] = producer_data.index


# pie plot
fig = px.pie(producer_data,
             values="Producer %",
             names="Name",
             title="Producer of the Game",
             template="seaborn",width=1200,height=1000)
fig.update_traces(textposition="inside", textinfo="value+percent+label")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
producer_data = pd.DataFrame(Computer_Games['Producer'].value_counts().head(10))
producer_data.rename(columns={"Producer": "Number of Producer"}, inplace=True)
total_producer = producer_data["Number of Producer"].sum()
producer_data["Producer %"] = round(producer_data["Number of Producer"] / total_producer * 100, 2)
producer_data["Name"] = producer_data.index


# pie plot
fig = px.pie(producer_data,
             values="Producer %",
             names="Name",
             title="Producer of the Game",
             template="seaborn",width=1200,height=1000)
fig.update_traces(textposition="inside", textinfo="value+percent+label")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
genre_data = pd.DataFrame(Computer_Games['Genre'].value_counts())
genre_data.rename(columns={"Genre": "Number of Genre"}, inplace=True)
total_genre = genre_data["Number of Genre"].sum()
genre_data["Genre %"] = round(genre_data["Number of Genre"] / total_genre * 100, 2)
genre_data["Name"] = genre_data.index


# pie plot
fig = px.pie(genre_data,
             values="Genre %",
             names="Name",
             title="Genre of the Game",
             template="seaborn",width=1000,height=1000)
fig.update_traces(textposition="inside", textinfo="value+percent+label")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
genre_data = pd.DataFrame(Computer_Games['Genre'].value_counts().head(10))
genre_data.rename(columns={"Genre": "Number of Genre"}, inplace=True)
total_genre = genre_data["Number of Genre"].sum()
genre_data["Genre %"] = round(genre_data["Number of Genre"] / total_genre * 100, 2)
genre_data["Name"] = genre_data.index


# pie plot
fig = px.pie(genre_data,
             values="Genre %",
             names="Name",
             title="Genre of the Game",
             template="seaborn",width=1000,height=1000)
fig.update_traces(textposition="inside", textinfo="value+percent+label")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
operating_system_data = pd.DataFrame(Computer_Games['Operating System'].value_counts())
operating_system_data.rename(columns={"Operating System": "Number of Operating System"}, inplace=True)
total_operating_system = operating_system_data["Number of Operating System"].sum()
operating_system_data["Operating System %"] = round(operating_system_data["Number of Operating System"] / total_operating_system * 100, 2)
operating_system_data["Name"] = operating_system_data.index


# pie plot
fig = px.pie(operating_system_data,
             values="Operating System %",
             names="Name",
             title="Operating System",
             template="seaborn",width=1000,height=1000)
fig.update_traces(textposition="inside", textinfo="value+percent+label")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
operating_system_data = pd.DataFrame(Computer_Games['Operating System'].value_counts().head(10))
operating_system_data.rename(columns={"Operating System": "Number of Operating System"}, inplace=True)
total_operating_system = operating_system_data["Number of Operating System"].sum()
operating_system_data["Operating System %"] = round(operating_system_data["Number of Operating System"] / total_operating_system * 100, 2)
operating_system_data["Name"] = operating_system_data.index


# pie plot
fig = px.pie(operating_system_data,
             values="Operating System %",
             names="Name",
             title="Operating System",
             template="seaborn",width=1000,height=1000)
fig.update_traces(textposition="inside", textinfo="value+percent+label")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
